# %%
# !pip install langchain-huggingface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 720.3 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 396.2/396.2 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.1/227.1 kB 9.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.7/150.7 kB 6.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.9/141.9 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 2.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 9.0.0
#     Uninstalling tenacity-9.0.0:
#       Successfully uninstalled tenacity-9.0.0
# ...

# %%
# !pip install huggingface_hub
# !pip install transformers
# !pip install accelerate
# !pip install bitsandbytes
# !pip install langchain
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 MB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 4.5 MB/s eta 0:00:00
# ...

# %% [markdown]
# Here i am using sec key which was made using the token from the hugging face and the key was stored somewhere as for the later use.

# %%
from langchain_huggingface import HuggingFaceEndpoint

# %%
from google.colab import userdata
sec_key=userdata.get('Hug_Api_Token')
print(sec_key)
# Out:
# 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

# %%
import os
os.environ['Hug_Api_Token']=sec_key

# %% [markdown]
# through the hugging face end point we have just called the mistral 0.3v through an api where my token sec key  is given over there as hug_api_token  and now i can just use llm.invoke to get the ANSWER oF MY GIVEN QUESTION

# %%
repo_id = 'mistralai/Mistral-7B-Instruct-v0.3'
llm=HuggingFaceEndpoint(repo_id=repo_id,temperature=0.7)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
llm.invoke('What is deep Learning ')
# Out:
# '2? Deep Learning 2 refers to the second generation of deep learning techniques, which emerged after the initial success of deep learning in the late 2000s and early 2010s. This second generation of deep learning is characterized by several key advancements:\n\n1. **Improved architectures**: Deep Learning 2 saw the emergence of more complex and effective neural network architectures, such as Convolutional Neural Networks (CNNs) for image recognition and Recurrent Neural Networks (RNNs) for sequential data.\n\n2. **Emergence of deep learning libraries**: Libraries like TensorFlow, PyTorch, and Keras were developed, making it easier for researchers and practitioners to build and train deep learning models.\n\n3. **Deep reinforcement learning**: Deep Learning 2 also saw the rise of deep reinforcement learning, which combines deep learning with reinforcement learning to enable agents to learn complex behaviors through trial and error.\n\n4. **Improved training techniques**: Techniques li
# ...

# %% [markdown]
# Below is the new way of putting the ToKen once and use it multiple times .

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
repo_id = 'openai-community/gpt2'
llm=HuggingFaceEndpoint(repo_id=repo_id,temperature=0.7)

# %%
llm.invoke('What is Data Science')
# Out:
# '?\n\nData science is a discipline in which researchers work on a problem, in a way, from a theoretical point of view, to a practical point of view, to reach a goal, to achieve something. This is a very different approach than what we typically see in traditional field work. In fact, many of the concepts that are used in the field of Data Science are in our traditional field work.\n\nIn the field of Data Science, we focus on the concepts that are commonly used in data science to solve problems. For example, we focus on the concepts of "data", "datasets", "data science", "data science" and "data science". We focus on the types of data and the concepts of "data science", "data science", "data science" and "data science".\n\nIn this chapter, we will look at the concepts that are commonly used in data science to solve problems. We will also talk about how these concepts are used in the field of Data Science.\n\nData Science Concepts\n\nThe concept of "data science" is a more general term
# ...

# %%
from langchain import PromptTemplate , LLMChain

question = 'How many moon do saturn have, tell me in numbers'
template = '''Question:{question}
answer: lets think a out this'''
prompt = PromptTemplate(template=template , input_variable=['question'])
print(prompt)
# Out:
# input_variables=['question'] template='Question:{question}\nanswer: lets think a out this'

# %%
llm_chain = LLMChain(llm=llm , prompt= prompt)
print(llm_chain.invoke(question))
# Out:
# {'question': 'How many moon do saturn have, tell me in numbers', 'text': ", but we can add a few more in the middle, so we can get a number like this, and then we can add another, you know, we can take all these numbers and we can add one more, and then we can multiply this, you know, and then we can multiply this another, you know, we can add a number, we can multiply this, and so forth.\nWe can do all this in just one go, you know, so we can get a number like this, and then we can add it all together, you know, and so forth.\nWe can do it in just a few minutes, you know, and then we can get back to the idea of the moon.\nSo, the idea of the moon is that there are a number of different kinds of planets that orbit the sun. These are called planets. And we're going to give you a bunch of planets in this series, and then we'll give you a bunch of planets in this series, and then we'll give you a bunch of planets in this series, and then we'll give you a bunch of planets in this series.
# ...

# %% [markdown]
# HUGGING FACE PIPELINE

# %%
# !pip install --upgrade transformers
from transformers import AutoTokenizer,AutoModelForCausalLM, pipeline
from langchain_huggingface import HuggingFacePipeline
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 624.6 kB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 27.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.42.4
#     Uninstalling transformers-4.42.4:
#       Successfully uninstalled transformers-4.42.4
# ...

# %%
model_id =  'openai-community/gpt2'
model=AutoModelForCausalLM.from_pretrained(model_id)
tokenizer = AutoTokenizer.from_pretrained(model_id)
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
pipe = pipeline('text-generation',model=model,tokenizer=tokenizer,max_new_tokens=100)
hf= HuggingFacePipeline(pipeline=pipe)

# %%
hf
# Out:
# HuggingFacePipeline(pipeline=<transformers.pipelines.text_generation.TextGenerationPipeline object at 0x7e299209fdc0>)

# %%
hf.invoke("Paytm is a comany")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 'Paytm is a comanyment that makes your home better.\n\nUse Your Account to Paytm Visit the Home Office and download our mobile application for more information about payment transactions.\n\nContact us to be added.'

# %%
gpu_llm= HuggingFacePipeline.from_model_id(model_id='openai-community/gpt2',task='text-generation', pipeline_kwargs={'max_new_tokens':100})
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(

# %%
from langchain import PromptTemplate , LLMChain

template = '''Question:{question}
answer: Answer is '''
prompt = PromptTemplate.from_template(template)
print(prompt)
# Out:
# input_variables=['question'] template='Question:{question}\nanswer: Answer is '

# %%
chain =prompt|gpu_llm

# %%
question="Who is The Prime Minister of INDIA"
chain.invoke({"question":question})
# Out:
# "Question:Who is The Prime Minister of INDIA\nanswer: Answer is ia\nI have asked the Chief Secretaries of the Government in India to send to me the answer to this question\nanswer: Answer is ia\nI ask you to send me The prime minister of India\nIn this case I have been sent\nThe prime minister of India\nAnswer:Answer is ia\nSo, I don't like this answer but I have heard.\nIf you have a question about the country or about your job you should say you do not want to answer them"

# %%
question="What is the value of x"
chain.invoke({"question":question})
# Out:
# "Question:What is the value of x\nanswer: Answer is ix, and x is the number of the left hand. This value is: x = x + (2 + y)\nAnswer the question and you'll now know why there is a value that is 0 when the right hand is being played. Answer the answer, and you'll know why you have a value greater than 0. If you want proof that the right card is doing the right thing, then look at this question: Suppose two players have a board and two cards. You and your"
